# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/processed/final.csv")
df.head()
# Out:
#         Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  0.536681       Yes      Travel_Rarely   0.734325                   Sales
# 1  1.442111        No  Travel_Frequently  -1.307769  Research & Development
# 2  0.083966       Yes      Travel_Rarely   1.406752  Research & Development
# 3 -0.368749        No  Travel_Frequently   1.453896  Research & Development
# 4 -1.047821        No      Travel_Rarely  -0.533609  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0         -1.011249  -0.876177  Life Sciences            0.0       -1.702014
# 1         -0.145521  -1.853858  Life Sciences            0.0       -1.700354
# 2         -0.887573  -0.876177          Other            0.0       -1.697034
# 3         -0.763898   1.079185  Life Sciences            0.0       -1.695374
# 4         -0.887573  -1.853858        Medical            0.0       -1.692054
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                 -1.575817           0.0         -0.929427
# 1  ...                  1.199034           0.0          0.238250
# 2  ...                 -0.650866           0.0         -0.929427
# 3  ...                  0.274084           0.0         -0.929427
# 4  ...                  1.199034           0.0          0.238250
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0          -0.343728              -2.171420       -2.501172       -0.022350
# 1          -0.045106               0.151871        0.336558        0.832812
# 2          -0.493039               0.151871        0.336558       -1.305094
# 3          -0.343728               0.151871        0.336558        0.405231
# 4          -0.642351               0.151871        0.336558       -0.877513
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0           0.040903                -0.710699              0.368270
# 1           0.965895                -0.310480              0.982200
# 2          -1.192419                -0.710699             -1.166556
# 3           0.965895                 0.489958             -1.166556
# 4          -0.575758                 0.089739             -0.552626
#
# [5 rows x 35 columns]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1387 entries, 0 to 1386
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1387 non-null   float64
#  1   Attrition                 1387 non-null   str
#  2   BusinessTravel            1387 non-null   str
#  3   DailyRate                 1387 non-null   float64
#  4   Department                1387 non-null   str
#  5   DistanceFromHome          1387 non-null   float64
#  6   Education                 1387 non-null   float64
#  7   EducationField            1387 non-null   str
#  8   EmployeeCount             1387 non-null   float64
#  9   EmployeeNumber            1387 non-null   float64
#  10  EnvironmentSatisfaction   1387 non-null   float64
#  11  Gender                    1387 non-null   str
#  12  HourlyRate                1387 non-null   float64
#  13  JobInvolvement            1387 non-null   float64
#  14  JobLevel                  1387 non-null   float64
#  15  JobRole                   1387 non-null   str
#  16  JobSatisfaction           1387 non-null   float64
#  17  MaritalStatus             1387 non-null   str
#  18  MonthlyIncome             1387 non-null   float64
#  19  MonthlyRate               1387 non-null   float64
#  20  NumCompaniesWorked        1387 non-null   float64
#  21  Over18                    1387 non-null   str
#  22  OverTime                  1387 non-null   str
#  23  PercentSalaryHike         1387 non-null   float64
#  24  PerformanceRating         1387 non-null   float64
#  25  RelationshipSatisfaction  1387 non-null   float64
#  26  StandardHours             1387 non-null   float64
#  27  StockOptionLevel          1387 non-null   float64
#  28  TotalWorkingYears         1387 non-null   float64
#  29  TrainingTimesLastYear     1387 non-null   float64
#  30  WorkLifeBalance           1387 non-null   float64
#  31  YearsAtCompany            1387 non-null   float64
#  32  YearsInCurrentRole        1387 non-null   float64
#  33  YearsSinceLastPromotion   1387 non-null   float64
#  34  YearsWithCurrManager      1387 non-null   float64
# dtypes: float64(26), str(9)
# memory usage: 379.4 KB
#                 Age     DailyRate  DistanceFromHome     Education  \
# count  1.387000e+03  1.387000e+03      1.387000e+03  1.387000e+03
# mean  -3.092936e-16 -3.073725e-17      1.280719e-17 -8.196600e-17
# std    1.000361e+00  1.000361e+00      1.000361e+00  1.000361e+00
# min   -2.066430e+00 -1.746955e+00     -1.011249e+00 -1.853858e+00
# 25%   -7.082852e-01 -8.400474e-01     -8.875735e-01 -8.761768e-01
# 50%   -1.423914e-01  2.347108e-03     -2.691967e-01  1.015040e-01
# 75%    6.498599e-01  8.782389e-01      5.965307e-01  1.079185e+00
# max    2.687077e+00  1.716911e+00      2.451661e+00  2.056866e+00
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction    HourlyRate  \
# count         1387.0    1.387000e+03             1.387000e+03  1.387000e+03
# mean             0.0    1.639320e-16            -7.428168e-17  3.432326e-16
# std              0.0    1.000361e+00             1.000361e+00  1.000361e+00
# min              0.0   -1.702014e+00            -1.582635e+00 -1.768199e+00
# 25%              0.0   -8.910997e-01            -6.653285e-01 -8.803300e-01
# 50%              0.0   -7.145099e-03             2.519783e-01  7.539386e-03
# 75%              0.0    8.817895e-01             1.169285e+00  8.460827e-01
# max              0.0    1.729224e+00             1.169285e+00  1.684626e+00
#
#        JobInvolvement      JobLevel  ...  RelationshipSatisfaction  \
# count    1.387000e+03  1.387000e+03  ...              1.387000e+03
# mean    -1.972307e-16 -8.196600e-17  ...             -3.073725e-17
# std      1.000361e+00  1.000361e+00  ...              1.000361e+00
# min     -2.444483e+00 -9.414323e-01  ...             -1.575817e+00
# 25%     -1.034126e+00 -9.414323e-01  ...             -6.508663e-01
# 50%      3.762308e-01  4.330873e-02  ...              2.740841e-01
# 75%      3.762308e-01  4.330873e-02  ...              1.199034e+00
# max      1.786588e+00  2.997532e+00  ...              1.199034e+00
#
#        StandardHours  StockOptionLevel  TotalWorkingYears  \
# count         1387.0      1.387000e+03       1.387000e+03
# mean             0.0      2.049150e-17      -9.733462e-17
# std              0.0      1.000361e+00       1.000361e+00
# min              0.0     -9.294273e-01      -1.538219e+00
# 25%              0.0     -9.294273e-01      -6.423508e-01
# 50%              0.0      2.382499e-01      -1.944169e-01
# 75%              0.0      2.382499e-01       4.028283e-01
# max              0.0      2.573604e+00       3.538366e+00
#
#        TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# count           1.387000e+03     1.387000e+03    1.387000e+03
# mean            5.122875e-18     1.402387e-16   -2.689509e-17
# std             1.000361e+00     1.000361e+00    1.000361e+00
# min            -2.171420e+00    -2.501172e+00   -1.305094e+00
# 25%            -6.225595e-01    -1.082307e+00   -6.637220e-01
# 50%             1.518710e-01     3.365585e-01   -2.361408e-01
# 75%             1.518710e-01     3.365585e-01    6.190217e-01
# max             2.475162e+00     1.755424e+00    4.039672e+00
#
#        YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# count        1.387000e+03             1.387000e+03          1.387000e+03
# mean         3.842156e-18             3.393905e-17         -2.881617e-17
# std          1.000361e+00             1.000361e+00          1.000361e+00
# min         -1.192419e+00            -7.106989e-01         -1.166556e+00
# 25%         -5.757580e-01            -7.106989e-01         -5.526258e-01
# 50%         -2.674274e-01            -3.104799e-01         -2.456606e-01
# 75%          9.658952e-01             8.973908e-02          9.821999e-01
# max          3.432540e+00             3.691710e+00          3.130956e+00
#
# [8 rows x 26 columns]

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
plt.figure(figsize=(14,10))

numeric_df = df.select_dtypes(include=["int64", "float64"])
sns.heatmap(numeric_df.corr(), cmap="coolwarm")

plt.title("Correlation Matrix (Numerical Features Only)")
plt.show()

# %%
df.hist(figsize=(16,12), bins=30)
plt.tight_layout()
plt.show()

# %%
sns.countplot(x="Attrition", data=df)
plt.title("Attrition Distribution")
plt.show()
